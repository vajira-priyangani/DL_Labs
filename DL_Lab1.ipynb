# %%
### Task 1 - IT20107000 ###

# %%
import numpy as np

# %%
np.random.rand(4,4)
# Out:
# array([[0.26584528, 0.63754623, 0.25552658, 0.70027442],
#        [0.99149043, 0.10215774, 0.79928347, 0.06513663],
#        [0.77911139, 0.04209151, 0.67013889, 0.33267231],
#        [0.30270684, 0.43991159, 0.12136432, 0.34858217]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.hist(np.random.rand(100000), density=True, bins=100, histtype="step", color="blue", label="rand")
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
plt.hist(np.random.rand(100000), density=True, bins=1, histtype="step", color="blue", label="rand")
plt.axis([-2.5, 2.5, 0, 1.1])
plt.legend(loc = "upper left")
plt.title("Random distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
import matplotlib

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5)
y = np.linspace(-5, 5)
X, Y = np.meshgrid(x, y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

figure = plt.figure(1, figsize = (12, 4))
subplot3d = plt.subplot(111, projection='3d')
surface = subplot3d.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=matplotlib.cm.coolwarm, linewidth=0.1)
plt.show()

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Au_nanoparticle_dataset.csv', index_col=0, encoding='latin')

# %%
df.head()
# Out:
#       T       tau  time  N_total  N_bulk  N_surface        Volume    R_min  \
# ID
# 1   273  0.000025     1     1599    1014        585  2.710000e-26  15.5898
# 2   273  0.000025     2     1642    1034        608  2.780000e-26  15.3996
# 3   273  0.000025     3     4637    3365       1272  7.850000e-26  21.9199
# 4   273  0.000025     4     7189    5292       1897  1.220000e-25  23.2542
# 5   273  0.000025     5    11004    8508       2496  1.860000e-25  27.1200
#
#       R_max   R_diff  ...  q6q6_S14  q6q6_S15  q6q6_S16  q6q6_S17  q6q6_S18  \
# ID                    ...
# 1   19.4516   3.8618  ...         0         0         0         0         0
# 2   24.1755   8.7760  ...         0         0         0         0         0
# 3   31.0305   9.1106  ...         0         0         0         0         0
# 4   37.8795  14.6253  ...         0         0         0         0         0
# 5   39.7614  12.6415  ...         0         0         0         0         0
#
# ...

# %%
import piplite
await piplite.install('seaborn')

# %%
import seaborn as sns

# %%
plt.figure(figsize=(9,6)) 
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
 
corr
# Out:
#                     T       tau      time   N_total    N_bulk  N_surface  \
# T            1.000000 -0.036333  0.033817 -0.014396 -0.004974  -0.052871
# tau         -0.036333  1.000000 -0.639896  0.009165 -0.006485   0.073452
# time         0.033817 -0.639896  1.000000  0.060622  0.064611   0.042594
# N_total     -0.014396  0.009165  0.060622  1.000000  0.998776   0.978982
# N_bulk      -0.004974 -0.006485  0.064611  0.998776  1.000000   0.967695
# ...               ...       ...       ...       ...       ...        ...
# q6q6_S19          NaN       NaN       NaN       NaN       NaN        NaN
# q6q6_S20          NaN       NaN       NaN       NaN       NaN        NaN
# q6q6_S20+         NaN       NaN       NaN       NaN       NaN        NaN
# Total_E      0.029147 -0.011413 -0.058270 -0.999716 -0.998495  -0.978691
# Formation_E  0.248701 -0.032021  0.096280  0.906140  0.904981   0.887304
#
#                Volume     R_min     R_max    R_diff  ...  q6q6_S14  q6q6_S15  \
# ...

# %%
plt.figure(figsize=(9,8))
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
### TASK 2 - IT20107000 ###

# %%
import pandas as pd

# %%
import piplite
await piplite.install('seaborn')

# %%
import seaborn as sns

# %%
nanopracticle_df = pd.read_csv('Au_nanoparticle_dataset.csv', index_col=0, encoding='latin')

# %%
selected_columns = ['N_total', 'N_bulk', 'N_surface', 'R_avg']
nanopracticle_df = df[selected_columns].copy()

# %%
print(nanopracticle_df.head(20))
# Out:
#     N_total  N_bulk  N_surface    R_avg
# ID
# 1      1599    1014        585  17.3706
# 2      1642    1034        608  17.6061
# 3      4637    3365       1272  25.3692
# 4      7189    5292       1897  29.7011
# 5     11004    8508       2496  34.2831
# 6     13375   10768       2607  36.6334
# 7     13795   11155       2640  37.0108
# 8     13947   11304       2643  37.1672
# 9     14020   11357       2663  37.2103
# 10    14056   11389       2667  37.2467
# 11     1534     966        568  17.1107
# 12     1559     974        585  17.2101
# 13     4356    3099       1257  24.8253
# 14     6550    4675       1875  29.0376
# 15    10175    7748       2427  33.4399
# 16    12393    9842       2551  35.6950
# 17    13207   10590       2617  36.4657
# 18    13543   10937       2606  36.7871
# 19    13713   11079       2634  36.9333
# 20    13791   11151       2640  37.0104

# %%
calculation = nanopracticle_df.describe()
print(calculation)
# Out:
#             N_total        N_bulk   N_surface        R_avg
# count   4000.000000   4000.000000  4000.00000  4000.000000
# mean    3476.786500   2521.550250   955.23625    20.654363
# std     3679.286769   2976.232459   721.87022     7.610716
# min      236.000000     89.000000   137.00000     8.528600
# 25%     1061.000000    618.750000   437.00000    15.160725
# 50%     1867.000000   1199.000000   666.00000    18.629250
# 75%     4503.000000   3183.000000  1301.75000    25.525125
# max    14277.000000  11580.000000  3190.00000    39.239200

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
nanopracticle_df.hist(figsize=(20, 4))
plt.tight_layout()
plt.show()

# %%
sns.pairplot(nanopracticle_df)
plt.show()

# %%
g = sns.PairGrid(nanopracticle_df)

# %%
g.map_diag(sns.histplot, kde=True)

# %%
g.map_upper(plt.scatter)

# %%
g.map_lower(sns.kdeplot, cmap='Blues_d')

# %%
plt.show()

# %%
g = sns.PairGrid(nanopracticle_df)
g.map_diag(sns.histplot, kde=True)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot, cmap='Blues_d')
plt.show()
